# %% [markdown]
# # Explora aquí
#
# Se recomienda utilizar este cuaderno con fines de exploración.

# %%
import os
from bs4 import BeautifulSoup
import requests
import time
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns

# %%
resource_url = 'https://www.fc-moto.de/epages/fcm.sf/es_ES/;IC_DeliveryCountry=ES;IC_IP2Location_Locale=es_ES;IC_TargetCurrency=EUR;IC_TopicWorld=2587640?ObjectID=2587584&ViewAction=FacetedSearchProducts&SearchString=cascos'
agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
headers = {"User-Agent": agent}
response = requests.get(resource_url, headers=headers)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content,'html')
soup
# Out:
# <!-- BEGIN INCLUDE CookieFix writeContentOutput 0.005 seconds --><!-- FindologicSearchTime 0.517 seconds --><!-- SolrSearchTime  seconds --><!-- BEGIN INCLUDE TrackingSwitchContent 0.196 seconds --><!-- BEGIN INCLUDE ReplacePricingContent 0.381 seconds --><!-- BEGIN INCLUDE CookieFix processContent 0.199 seconds --><!DOCTYPE html>
# <!--[if lt IE 7 ]> <html class="ie6" lang="es"> <![endif]--><!--[if IE 7 ]> <html class="ie7" lang="es"> <![endif]--><!--[if IE 8 ]> <html class="ie8" lang="es"> <![endif]--><!--[if IE 9 ]> <html class="ie9" lang="es"> <![endif]--><!--[if (gt IE 9)|!(IE)]><!--><html class="no-js" lang="es"> <!--<![endif]-->
# <head>
# <meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# ...

# %%
product_name = soup.find_all('h3', class_="Headline")
product_price = soup.find_all('span', class_='Price PriceIsHot')
# Out:
# '\n139,99 €\n\n'

# %%
list_products = []
for product in soup:
  list_products.append({'Headline': product_name,
                        'Price PriceIsHot': product_price})

list_products
# Out:
# [{'Headline': [<h3 class="Headline">
#    <a href="?ObjectPath=/Shops/10207048/Products/Bogotto-H271-Taog-Bluetooth-Helmet-24/SubProducts/Bogotto-H271-Taog-Bluetooth-Helmet-24-0001" itemprop="url" title="Bogotto H271 Taog Bluetooth Casco"><span itemprop="name">Bogotto H271 Taog Bluetooth Casco</span></a>
#    </h3>,
#    <h3 class="Headline">
#    <a href="?ObjectPath=/Shops/10207048/Products/Bogotto-H128-Fiori-Helmet/SubProducts/Bogotto-H128-Fiori-Helmet-0006" itemprop="url" title="Bogotto H128 Fiori Casco"><span itemprop="name">Bogotto H128 Fiori Casco</span></a>
#    </h3>,
#    <h3 class="Headline">
#    <a href="?ObjectPath=/Shops/10207048/Products/FC-Moto-FF130SV-Cavion-Solid-Helmet-2025/SubProducts/FC-Moto-FF130SV-Cavion-Solid-Helmet-2025-0009" itemprop="url" title="FC-Moto FF130SV Casco"><span itemprop="name">FC-Moto FF130SV Casco</span></a>
#    </h3>,
#    <h3 class="Headline">
# ...
